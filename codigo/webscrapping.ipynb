# %%
pip install beautifulsoup4 requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# ========= SCRAPING PC COMPONENTES: MONITORES GAMING (PRIMERA PÁGINA) =========

import requests
from bs4 import BeautifulSoup
import pandas as pd

# 1. URL de ejemplo: monitores gaming (ajusta si hace falta)
BASE_URL = "https://www.pccomponentes.com/monitores-gaming"

headers = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/123.0.0.0 Safari/537.36"
    )
}

def get_page_html(url):
    response = requests.get(url, headers=headers)
    response.raise_for_status()
    return response.text

def parse_product_list(html):
    soup = BeautifulSoup(html, "html.parser")
    
    # OJO: estos selectores hay que ajustarlos mirando el HTML real de PCComponentes
    # Abre la web, inspecciona una tarjeta de producto y cambia estas clases si no coinciden.
    product_cards = soup.select("article.sc-product-card")
    print("Nº de tarjetas encontradas dentro de la función:", len(product_cards))
    
    data = []
    for card in product_cards:
        # Nombre del producto
        name_el = card.select_one(".sc-product-card__title")
        name = name_el.get_text(strip=True) if name_el else None
        
        # Precio actual
        price_el = card.select_one(".sc-product-card__price")
        price_text = price_el.get_text(strip=True) if price_el else None
        
        # Precio original (si hay descuento)
        original_el = card.select_one(".sc-product-card__price--previous")
        original_price_text = original_el.get_text(strip=True) if original_el else None
        
        # Rating (estrellas)
        rating_el = card.select_one(".sc-product-card__rating")
        rating = rating_el.get("data-rating") if rating_el else None
        
        # Número de opiniones
        reviews_el = card.select_one(".sc-product-card__reviews")
        reviews_text = reviews_el.get_text(strip=True) if reviews_el else None
        
        data.append({
            "nombre": name,
            "precio_actual_raw": price_text,
            "precio_original_raw": original_price_text,
            "rating_raw": rating,
            "opiniones_raw": reviews_text,
            "url_categoria": BASE_URL
        })
    
    return data

# 2. Ejecutar scraping de la primera página y mostrar resultados
html = get_page_html(BASE_URL)
productos = parse_product_list(html)

print("Nº de productos encontrados:", len(productos))

df = pd.DataFrame(productos)
print(df.head())
# Out:
# Nº de tarjetas encontradas dentro de la función: 0
# Nº de productos encontrados: 0
# Empty DataFrame
# Columns: []
# Index: []

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

BASE_URL = "https://www.pccomponentes.com/monitores-pc"

headers = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/123.0.0.0 Safari/537.36"
    )
}

def get_page_html(url):
    response = requests.get(url, headers=headers)
    response.raise_for_status()
    return response.text

def parse_product_list(html):
    soup = BeautifulSoup(html, "html.parser")
    
    product_cards = soup.select("div.product-card")
    print("Nº de tarjetas encontradas dentro de la función:", len(product_cards))
    
    data = []
    for card in product_cards:
        # Nombre
        name_el = card.select_one("a.product-card__name") or card.select_one("a[title]")
        name = name_el.get_text(strip=True) if name_el else None
        
        # Precio actual: buscamos cualquier elemento con "€" dentro del card
        price_el = None
        for el in card.select("*"):
            text = el.get_text(strip=True)
            if "€" in text:
                price_el = el
                break
        price_text = price_el.get_text(strip=True) if price_el else None
        
        # Precio original (si hay precio tachado, suele aparecer distinto)
        original_price_text = None
        # Si ves en el HTML una clase concreta para el precio tachado, cámbiala aquí:
        original_el = card.select_one(".price-old, .product-card__price-regular")
        if original_el:
            original_price_text = original_el.get_text(strip=True)
        
        # Rating y opiniones: de momento dejamos placeholders
        rating_el = card.select_one(".product-card__rating")
        rating_text = rating_el.get_text(strip=True) if rating_el else None
        
        reviews_el = card.select_one(".product-card__reviews")
        reviews_text = reviews_el.get_text(strip=True) if reviews_el else None
        
        data.append({
            "nombre": name,
            "precio_actual_raw": price_text,
            "precio_original_raw": original_price_text,
            "rating_raw": rating_text,
            "opiniones_raw": reviews_text,
            "url_categoria": BASE_URL
        })
    
    return data

# Ejecutar scraping de la primera página y mostrar resultados
html = get_page_html(BASE_URL)
productos = parse_product_list(html)

print("Nº de productos encontrados:", len(productos))

df = pd.DataFrame(productos)
print(df.head())
# Out:
# Nº de tarjetas encontradas dentro de la función: 40
# Nº de productos encontrados: 40
#   nombre precio_actual_raw precio_original_raw rating_raw opiniones_raw  \
# 0   None              None                None       None          None
# 1   None              None                None       None          None
# 2   None              None                None       None          None
# 3   None              None                None       None          None
# 4   None              None                None       None          None
#
#                                 url_categoria
# 0  https://www.pccomponentes.com/monitores-pc
# 1  https://www.pccomponentes.com/monitores-pc
# 2  https://www.pccomponentes.com/monitores-pc
# 3  https://www.pccomponentes.com/monitores-pc
# 4  https://www.pccomponentes.com/monitores-pc

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Ejemplo: monitores de PC (ajusta la URL a la categoría que quieras)
BASE_URL = "https://www.pccomponentes.com/monitores-pc"

headers = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/123.0.0.0 Safari/537.36"
    )
}

def get_page_html(url):
    resp = requests.get(url, headers=headers)
    resp.raise_for_status()
    return resp.text

def parse_product_list(html):
    soup = BeautifulSoup(html, "html.parser")
    
    # Cada producto tiene un <a> con un montón de data-product-*
    product_links = soup.select("a.link-O9JV8C[data-product-name]")
    print("Nº de productos encontrados:", len(product_links))
    
    data = []
    for link in product_links:
        # Atributos data-product-* (pueden no estar todos siempre)
        name = link.get("data-product-name")
        brand = link.get("data-product-brand")
        category = link.get("data-product-category")
        price_str = link.get("data-product-price")            # precio actual
        discount_pct_str = link.get("data-product-total-discount")  # descuento %
        sku = link.get("data-product-id")
        
        # Ahora buscamos dentro del product-card asociado el rating y nº opiniones
        card = link.find_parent("div", class_="container-iTDhwB")  # contenedor de la tarjeta
        rating_text = None
        reviews_text = None
        original_price_text = None
        
        if card:
            # Precio original tachado (si existe)
            crossed = card.select_one(".crossedOutPrice-onpNpk[data-e2e-crossed-price]")
            if crossed:
                original_price_text = crossed.get_text(strip=True)
            
            # Rating y nº opiniones
            rating_block = card.select_one(".ratingTypeOne-sExEq5")
            if rating_block:
                spans = rating_block.select("span")
                if len(spans) >= 1:
                    rating_text = spans[0].get_text(strip=True)
                if len(spans) >= 2:
                    reviews_text = spans[1].get_text(strip=True)
        
        data.append({
            "sku": sku,
            "nombre": name,
            "marca": brand,
            "categoria_raw": category,
            "precio_actual_raw": price_str,
            "precio_original_raw": original_price_text,
            "descuento_pct_raw": discount_pct_str,
            "rating_raw": rating_text,
            "opiniones_raw": reviews_text,
            "url_categoria": BASE_URL,
        })
    
    return data

html = get_page_html(BASE_URL)
productos = parse_product_list(html)

df = pd.DataFrame(productos)
print(df.head())
# Out:
# Nº de productos encontrados: 40
#         sku                                             nombre   marca  \
# 0  10878179  Monitor Alurin CoreVision 100IPSLite 22" FHD 1...  Alurin
# 1  10917630  PcCom Elysium Pro 27" Fast IPS QHD 200Hz 1ms A...   PcCom
# 2  10893932  Monitor gaming PcCom Elysium 27" Fast IPS FHD ...   PcCom
# 3  10756386  Alurin CoreVision 100IPSLite 23.8" FHD 100Hz F...  Alurin
# 4  10867508  AOC Q27G42XE 27" LED Fast IPS QHD 180Hz Altavo...     AOC
#
#   categoria_raw precio_actual_raw precio_original_raw descuento_pct_raw  \
# 0     Monitores             59.99                None                25
# 1     Monitores            124.99                None                32
# 2     Monitores            104.99                None                27
# 3     Monitores             69.99                None                26
# 4     Monitores             139.9                None                22
#
#   rating_raw opiniones_raw                               url_categoria
# ...

# %%
import numpy as np

# 1. Precio actual: de string a float
# precio_actual_raw viene como '59.99' o parecido
df["precio_actual"] = (
    df["precio_actual_raw"]
    .astype(str)
    .str.replace("€", "", regex=False)
    .str.replace(".", "", regex=False)   # por si viniera con separador de miles
    .str.replace(",", ".", regex=False)  # por si algún precio trae coma decimal
    .str.strip()
    .replace("", np.nan)
    .astype(float)
)

# 2. Descuento porcentual: de string a float
# descuento_pct_raw viene como '25', '32', etc.
df["descuento_pct"] = (
    df["descuento_pct_raw"]
    .astype(str)
    .str.replace("%", "", regex=False)
    .str.strip()
    .replace(["", "None", "nan"], np.nan)
    .astype(float)
)

# 3. Precio original: limpiar texto con €
df["precio_original"] = (
    df["precio_original_raw"]
    .astype(str)
    .str.replace("€", "", regex=False)
    .str.replace(".", "", regex=False)
    .str.replace(",", ".", regex=False)
    .str.strip()
    .replace(["", "None", "nan"], np.nan)
    .astype(float)
)

# 4. Crear columna de subcategoría "bonita" (por ahora igual a categoria_raw)
df["subcategoria"] = df["categoria_raw"].str.strip()

# 5. Ver resultado parcial
cols_ver = [
    "sku", "nombre", "marca",
    "subcategoria",
    "precio_actual_raw", "precio_actual",
    "precio_original_raw", "precio_original",
    "descuento_pct_raw", "descuento_pct"
]
print(df[cols_ver].head())
# Out:
#         sku                                             nombre   marca  \
# 0  10878179  Monitor Alurin CoreVision 100IPSLite 22" FHD 1...  Alurin
# 1  10917630  PcCom Elysium Pro 27" Fast IPS QHD 200Hz 1ms A...   PcCom
# 2  10893932  Monitor gaming PcCom Elysium 27" Fast IPS FHD ...   PcCom
# 3  10756386  Alurin CoreVision 100IPSLite 23.8" FHD 100Hz F...  Alurin
# 4  10867508  AOC Q27G42XE 27" LED Fast IPS QHD 180Hz Altavo...     AOC
#
#   subcategoria precio_actual_raw  precio_actual precio_original_raw  \
# 0    Monitores             59.99         5999.0                None
# 1    Monitores            124.99        12499.0                None
# 2    Monitores            104.99        10499.0                None
# 3    Monitores             69.99         6999.0                None
# 4    Monitores             139.9         1399.0                None
#
#    precio_original descuento_pct_raw  descuento_pct
# 0              NaN                25           25.0
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# URLs correctas de las 6 subcategorías
urls_categorias = {
    "PC": "https://www.pccomponentes.com/ordenadores-gaming",  # ← cambio aquí
    "Monitores": "https://www.pccomponentes.com/monitores-gaming",  # ← más específico
    "Teclados": "https://www.pccomponentes.com/teclados-gaming",
    "Ratones": "https://www.pccomponentes.com/ratones-gaming",
    "Cascos": "https://www.pccomponentes.com/auriculares-gaming",
    "Mandos": "https://www.pccomponentes.com/mandos-pc",
}

headers = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/123.0.0.0 Safari/537.36"
    )
}

def get_page_html(url):
    resp = requests.get(url, headers=headers)
    resp.raise_for_status()
    return resp.text

def parse_product_list(html, subcategoria_manual, url_base):
    soup = BeautifulSoup(html, "html.parser")
    
    product_links = soup.select("a.link-O9JV8C[data-product-name]")
    print(f"  → {len(product_links)} productos encontrados en {subcategoria_manual}")
    
    data = []
    for link in product_links:
        name = link.get("data-product-name")
        brand = link.get("data-product-brand")
        category = link.get("data-product-category")
        price_str = link.get("data-product-price")
        discount_pct_str = link.get("data-product-total-discount")
        sku = link.get("data-product-id")
        
        card = link.find_parent("div", class_="container-iTDhwB")
        rating_text = None
        reviews_text = None
        original_price_text = None
        
        if card:
            crossed = card.select_one(".crossedOutPrice-onpNpk[data-e2e-crossed-price]")
            if crossed:
                original_price_text = crossed.get_text(strip=True)
            
            rating_block = card.select_one(".ratingTypeOne-sExEq5")
            if rating_block:
                spans = rating_block.select("span")
                if len(spans) >= 1:
                    rating_text = spans[0].get_text(strip=True)
                if len(spans) >= 2:
                    reviews_text = spans[1].get_text(strip=True)
        
        data.append({
            "sku": sku,
            "nombre": name,
            "marca": brand,
            "subcategoria": subcategoria_manual,
            "categoria_raw": category,
            "precio_actual_raw": price_str,
            "precio_original_raw": original_price_text,
            "descuento_pct_raw": discount_pct_str,
            "rating_raw": rating_text,
            "opiniones_raw": reviews_text,
            "url_categoria": url_base,
        })
    
    return data

# Bucle para scrapear las 6 categorías
all_productos = []

for subcategoria, url in urls_categorias.items():
    print(f"Scrapeando: {subcategoria} ({url})")
    try:
        html = get_page_html(url)
        productos = parse_product_list(html, subcategoria, url)
        all_productos.extend(productos)
    except Exception as e:
        print(f"  ❌ Error en {subcategoria}: {e}")
    
    # Pausa de 2 segundos entre peticiones
    time.sleep(2)

# Crear DataFrame único
df = pd.DataFrame(all_productos)
print(f"\n✅ Total de productos scrapeados: {len(df)}")
print(f"✅ Subcategorías únicas: {df['subcategoria'].unique()}")
print("\nPrimeras filas:")
print(df.head(10))
# Out:
# Scrapeando: PC (https://www.pccomponentes.com/ordenadores-gaming)
#   → 45 productos encontrados en PC
# Scrapeando: Monitores (https://www.pccomponentes.com/monitores-gaming)
#   → 40 productos encontrados en Monitores
# Scrapeando: Teclados (https://www.pccomponentes.com/teclados-gaming)
#   → 40 productos encontrados en Teclados
# Scrapeando: Ratones (https://www.pccomponentes.com/ratones-gaming)
#   → 40 productos encontrados en Ratones
# Scrapeando: Cascos (https://www.pccomponentes.com/auriculares-gaming)
#   → 40 productos encontrados en Cascos
# Scrapeando: Mandos (https://www.pccomponentes.com/mandos-pc)
#   → 40 productos encontrados en Mandos
#
# ✅ Total de productos scrapeados: 245
# ✅ Subcategorías únicas: <StringArray>
# ['PC', 'Monitores', 'Teclados', 'Ratones', 'Cascos', 'Mandos']
# Length: 6, dtype: str
#
# Primeras filas:
#         sku                                             nombre  marca  \
# ...

# %%
# 1. Convertimos la lista de diccionarios en un DataFrame
# Usamos el nombre 'all_productos' que ya tienes en tu script
df_final = pd.DataFrame(all_productos)

# 2. Guardamos ese DataFrame en un CSV
df_final.to_csv("datos_scraping_gaming.csv", index=False, encoding='utf-8')

print("¡Archivo 'datos_scraping_gaming.csv' guardado correctamente!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 # 1. Convertimos la lista de diccionarios en un DataFrame
#       2 # Usamos el nombre 'all_productos' que ya tienes en tu script
# ----> 3 df_final = pd.DataFrame(all_productos)
#       4
#       5 # 2. Guardamos ese DataFrame en un CSV
#       6 df_final.to_csv("datos_scraping_gaming.csv", index=False, encoding='utf-8')
#
# NameError: name 'all_productos' is not defined

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
from pathlib import Path

urls_categorias = {
    "PC": "https://www.pccomponentes.com/ordenadores-gaming",
    "Monitores": "https://www.pccomponentes.com/monitores-gaming",
    "Teclados": "https://www.pccomponentes.com/teclados-gaming",
    "Ratones": "https://www.pccomponentes.com/ratones-gaming",
    "Cascos": "https://www.pccomponentes.com/auriculares-gaming",
    "Mandos": "https://www.pccomponentes.com/mandos-pc",
}

headers = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/123.0.0.0 Safari/537.36"
    )
}

def get_page_html(url):
    resp = requests.get(url, headers=headers)
    resp.raise_for_status()
    return resp.text

def parse_product_list(html, subcategoria_manual, url_base):
    soup = BeautifulSoup(html, "html.parser")
    product_links = soup.select("a.link-O9JV8C[data-product-name]")
    print(f"→ {len(product_links)} productos encontrados en {subcategoria_manual}")

    data = []

    for link in product_links:
        name = link.get("data-product-name")
        brand = link.get("data-product-brand")
        category = link.get("data-product-category")
        price_str = link.get("data-product-price")
        discount_pct_str = link.get("data-product-total-discount")
        sku = link.get("data-product-id")

        card = link.find_parent("div", class_="container-iTDhwB")
        rating_text = None
        reviews_text = None
        original_price_text = None

        if card:
            crossed = card.select_one(".crossedOutPrice-onpNpk[data-e2e-crossed-price]")
            if crossed:
                original_price_text = crossed.get_text(strip=True)

            rating_block = card.select_one(".ratingTypeOne-sExEq5")
            if rating_block:
                spans = rating_block.select("span")
                if len(spans) >= 1:
                    rating_text = spans[0].get_text(strip=True)
                if len(spans) >= 2:
                    reviews_text = spans[1].get_text(strip=True)

        data.append({
            "sku": sku,
            "nombre": name,
            "marca": brand,
            "subcategoria": subcategoria_manual,
            "categoria_raw": category,
            "precio_actual_raw": price_str,
            "precio_original_raw": original_price_text,
            "descuento_pct_raw": discount_pct_str,
            "rating_raw": rating_text,
            "opiniones_raw": reviews_text,
            "url_categoria": url_base,
        })

    return data

all_productos = []

for subcategoria, url in urls_categorias.items():
    print(f"Scrapeando: {subcategoria} ({url})")
    try:
        html = get_page_html(url)
        productos = parse_product_list(html, subcategoria, url)
        all_productos.extend(productos)
    except Exception as e:
        print(f"❌ Error en {subcategoria}: {e}")

    time.sleep(2)

df = pd.DataFrame(all_productos)

folder = Path(r"C:\Users\juanb\Desktop\IronHack\Proyecto individual\proyecto-analysis-gaming\Amazon Best-Selling Electronics Dataset 2025")
salida = folder / "datos_scraping_gaming.csv"

df.to_csv(salida, index=False, encoding="utf-8")

print(f"\n✅ Total de productos scrapeados: {len(df)}")
print(f"✅ Archivo guardado en: {salida}")
print(df.head())
# Out:
# Scrapeando: PC (https://www.pccomponentes.com/ordenadores-gaming)
# → 45 productos encontrados en PC
# Scrapeando: Monitores (https://www.pccomponentes.com/monitores-gaming)
# → 40 productos encontrados en Monitores
# Scrapeando: Teclados (https://www.pccomponentes.com/teclados-gaming)
# → 40 productos encontrados en Teclados
# Scrapeando: Ratones (https://www.pccomponentes.com/ratones-gaming)
# → 40 productos encontrados en Ratones
# Scrapeando: Cascos (https://www.pccomponentes.com/auriculares-gaming)
# → 40 productos encontrados en Cascos
# Scrapeando: Mandos (https://www.pccomponentes.com/mandos-pc)
# → 40 productos encontrados en Mandos
#
# ✅ Total de productos scrapeados: 245
# ✅ Archivo guardado en: C:\Users\juanb\Desktop\IronHack\Proyecto individual\proyecto-analysis-gaming\Amazon Best-Selling Electronics Dataset 2025\datos_scraping_gaming.csv
#         sku                                             nombre  marca  \
# ...
